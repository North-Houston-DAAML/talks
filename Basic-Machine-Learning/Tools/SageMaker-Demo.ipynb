# %%
################################################################################
#
# Creates a supervised learning model trained on bank customer data that
# predicts whether customers will order new certificates of deposits.
#
# Uses an XGBoost library algorithm.
#
# To run, do the following:
#
#         1. Visit https://console.aws.amazon.com/sagemaker .
#         2. Create a notebook instance using the default settings except for
#                    creating a new IAM role.
#         3. When the notebook is ready select "Open Jupyter".
#         4. In the notebook add the conda_python3 component.
#         5. Paste this code into a cell and run it.
#
# To shut down, execute the commented lines at the end.
#
# Code inspired by the tutorial located here:
#
#         https://aws.amazon.com/getting-started/hands-on/build-train-deploy-machine-learning-model-sagemaker/
#
################################################################################

import boto3
import sagemaker
import sagemaker.serializers
import numpy
import pandas
import urllib.request
import os

DATA_URL  = "https://d1.awsstatic.com/tmt/build-train-deploy-machine-learning-model-sagemaker/bank_clean.27f01fbbdf43271788427f3682996ae29ceca05d.csv"
S3_BUCKET = f"unused-bucket-name-{numpy.random.randint(1000000)}"
S3_FOLDER = "demo"
INSTANCE  = "ml.m4.xlarge"

# Saves the region name.

region = boto3.session.Session().region_name

# Creates a container with the necessary XGBoost code.

xgb_container = sagemaker.image_uris.retrieve("xgboost",
                                              region,
                                              "latest")

print(f"CREATED: SageMaker container {xgb_container} in region {region}")

# Creates an S3 bucket.

try:
        boto3.resource("s3").create_bucket(Bucket = S3_BUCKET)
        print(f"CREATED: bucket {S3_BUCKET}")
except:
        print("Error.")

# Downloads the data to a file and creates a corresponding Pandas dataframe.

try:
        urllib.request.urlretrieve (DATA_URL, "bank_clean.csv")
        all_data = pandas.read_csv("./bank_clean.csv", index_col = 0)
        print("CREATED: Pandas dataframe")
except:
        print("Error")

# Shuffles and splits the Pandas dataframe into two Pandas dataframes.

train_data, test_data = numpy.split(all_data.sample(frac = 1),
                                    [int(0.7 * len(all_data))])

print(f"CREATED: NumPy {train_data.shape} and {test_data.shape} arrays")

# Saves a modified version of the training data to a file.

modified = [train_data["y_yes"], train_data.drop(["y_no", "y_yes"], axis = 1)]
modified = pandas.concat(modified, axis = 1)
modified.to_csv("train_data.csv", index  = False, header = False)

# Saves the file to the S3 bucket.

train_path = os.path.join(S3_FOLDER, "train_data.csv")
bucket     = boto3.Session().resource("s3").Bucket(S3_BUCKET)
bucket.Object(train_path).upload_file("train_data.csv")

# Creates an S3 connection.

train_folder = f"s3://{S3_BUCKET}/{os.path.dirname(train_path)}"
s3_conn      = sagemaker.inputs.TrainingInput(s3_data      = train_folder,
                                              content_type = "csv")

print(f"CREATED: S3 connection to the folder {train_folder}")

# Creates a SageMaker training object configured with the following info:
#
#         hyperparameters
#         output folder
#         reference to the SageMaker XGBoost container
#         details of EC2 instances to use

s3_folder = f"s3://{S3_BUCKET}/{S3_FOLDER}"
session   = sagemaker.Session()
train_obj = sagemaker.estimator.Estimator(xgb_container,
                                          sagemaker.get_execution_role(),
                                          instance_count    = 1,
                                          instance_type     = INSTANCE,
                                          output_path       = s3_folder,
                                          sagemaker_session = session)
train_obj.set_hyperparameters(max_depth        = 5,
                              eta              = 0.2,
                              gamma            = 4,
                              min_child_weight = 6,
                              subsample        = 0.8,
                              silent           = 0,
                              objective        = "binary:logistic",
                              num_round        = 100)

print("CREATED: SageMaker training object")

# Does the training.

train_obj.fit({"train": s3_conn})

print("RESULT: Training completed.")

# Creates a model server.

model_server            = train_obj.deploy(initial_instance_count = 1,
                                           instance_type          = INSTANCE)
model_server.serializer = sagemaker.serializers.CSVSerializer()

print("CREATED: model server")

# Does the testing.

test_data_ = test_data.drop(["y_no", "y_yes"], axis = 1).values
results    = model_server.predict(test_data_).decode()
results    = numpy.round(numpy.fromstring(results[1:], sep = ","))
accuracy   = 100 * (results == test_data["y_yes"]).astype(int).mean()
print(f"RESULT: Accuracy is {accuracy:.1f}%.")

# Run these to delete the model server and bucket.

#model_server.delete_endpoint(delete_endpoint_config = True)
#boto3.resource("s3").Bucket(S3_BUCKET).objects.all().delete()
# Out:
# CREATED: SageMaker container 811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest in region us-east-1
# CREATED: bucket unused-bucket-name-140114
# CREATED: Pandas dataframe
# CREATED: NumPy (28831, 61) and (12357, 61) arrays
# CREATED: S3 connection to the folder s3://unused-bucket-name-140114/demo
# CREATED: SageMaker training object
# 2022-04-07 21:27:40 Starting - Starting the training job...
# 2022-04-07 21:28:08 Starting - Preparing the instances for trainingProfilerReport-1649366860: InProgress
# .........
# 2022-04-07 21:29:30 Downloading - Downloading input data......
# 2022-04-07 21:30:24 Training - Downloading the training image...
# 2022-04-07 21:31:07 Training - Training image download completed. Training in progress..Arguments: train
# [2022-04-07:21:31:10:INFO] Running standalone xgboost training.
# [2022-04-07:21:31:10:INFO] Path /opt/ml/input/data/validation does not exist!
# [2022-04-07:21:31:10:INFO] File size need to be processed in the node: 3.38mb. Available memory size in the node: 8499.5mb
# [2022-04-07:21:31:10:INFO] Determined delimiter of CSV input is ','
# [21:31:10] S3DistributionType set as FullyReplicated
# [21:31:10] 28831x59 matrix with 1701029 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [21:31:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 10 pruned nodes, max_depth=5
# [0]#011train-error:0.100898
# [21:31:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [1]#011train-error:0.100413
# [21:31:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 6 pruned nodes, max_depth=5
# [2]#011train-error:0.100274
# [21:31:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 18 pruned nodes, max_depth=5
# [3]#011train-error:0.100239
# [21:31:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=5
# [4]#011train-error:0.100864
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 20 pruned nodes, max_depth=5
# [5]#011train-error:0.100898
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 18 pruned nodes, max_depth=5
# [6]#011train-error:0.101037
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 28 pruned nodes, max_depth=5
# [7]#011train-error:0.100309
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 18 pruned nodes, max_depth=5
# [8]#011train-error:0.100586
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 18 pruned nodes, max_depth=5
# [9]#011train-error:0.100274
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 18 pruned nodes, max_depth=5
# [10]#011train-error:0.100274
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 26 pruned nodes, max_depth=5
# [11]#011train-error:0.100517
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 14 pruned nodes, max_depth=5
# [12]#011train-error:0.100205
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 22 pruned nodes, max_depth=5
# [13]#011train-error:0.100274
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 16 pruned nodes, max_depth=5
# [14]#011train-error:0.100482
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 10 pruned nodes, max_depth=5
# [15]#011train-error:0.100135
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 16 pruned nodes, max_depth=5
# [16]#011train-error:0.100135
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 14 pruned nodes, max_depth=5
# [17]#011train-error:0.100378
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 8 pruned nodes, max_depth=5
# [18]#011train-error:0.099927
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=5
# [19]#011train-error:0.099927
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 12 pruned nodes, max_depth=5
# [20]#011train-error:0.099962
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 10 pruned nodes, max_depth=5
# [21]#011train-error:0.09958
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=5
# [22]#011train-error:0.099511
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 18 pruned nodes, max_depth=5
# [23]#011train-error:0.099407
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 18 pruned nodes, max_depth=5
# [24]#011train-error:0.099233
# [21:31:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 16 pruned nodes, max_depth=5
# [25]#011train-error:0.098921
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [26]#011train-error:0.099095
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [27]#011train-error:0.099095
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 22 pruned nodes, max_depth=5
# [28]#011train-error:0.098991
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [29]#011train-error:0.098956
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 22 pruned nodes, max_depth=5
# [30]#011train-error:0.098991
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 14 pruned nodes, max_depth=5
# [31]#011train-error:0.098817
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [32]#011train-error:0.098644
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [33]#011train-error:0.098574
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [34]#011train-error:0.098228
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 16 pruned nodes, max_depth=5
# [35]#011train-error:0.098262
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 20 pruned nodes, max_depth=5
# [36]#011train-error:0.098193
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 24 pruned nodes, max_depth=5
# [37]#011train-error:0.098158
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 22 pruned nodes, max_depth=5
# [38]#011train-error:0.098054
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=5
# [39]#011train-error:0.098019
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 24 pruned nodes, max_depth=5
# [40]#011train-error:0.097707
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 16 pruned nodes, max_depth=5
# [41]#011train-error:0.097811
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=4
# [42]#011train-error:0.097673
# [21:31:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 20 pruned nodes, max_depth=5
# [43]#011train-error:0.097811
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [44]#011train-error:0.097603
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 26 pruned nodes, max_depth=5
# [45]#011train-error:0.097742
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=5
# [46]#011train-error:0.097777
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 18 pruned nodes, max_depth=5
# [47]#011train-error:0.097846
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 30 pruned nodes, max_depth=5
# [48]#011train-error:0.097673
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [49]#011train-error:0.097569
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 36 pruned nodes, max_depth=2
# [50]#011train-error:0.097569
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 24 pruned nodes, max_depth=3
# [51]#011train-error:0.097534
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 28 pruned nodes, max_depth=5
# [52]#011train-error:0.097638
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 24 pruned nodes, max_depth=3
# [53]#011train-error:0.09736
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 26 pruned nodes, max_depth=5
# [54]#011train-error:0.097326
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 18 pruned nodes, max_depth=5
# [55]#011train-error:0.097256
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [56]#011train-error:0.09736
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 34 pruned nodes, max_depth=0
# [57]#011train-error:0.09736
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 22 pruned nodes, max_depth=5
# [58]#011train-error:0.097014
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 28 pruned nodes, max_depth=5
# [59]#011train-error:0.096979
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 14 pruned nodes, max_depth=3
# [60]#011train-error:0.096875
# [21:31:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 30 pruned nodes, max_depth=3
# [61]#011train-error:0.09684
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=5
# [62]#011train-error:0.09684
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 14 pruned nodes, max_depth=5
# [63]#011train-error:0.096944
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 26 pruned nodes, max_depth=2
# [64]#011train-error:0.09684
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 32 pruned nodes, max_depth=0
# [65]#011train-error:0.09684
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 24 pruned nodes, max_depth=5
# [66]#011train-error:0.09684
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 34 pruned nodes, max_depth=5
# [67]#011train-error:0.097014
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 42 pruned nodes, max_depth=4
# [68]#011train-error:0.096979
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 20 pruned nodes, max_depth=5
# [69]#011train-error:0.09691
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 24 pruned nodes, max_depth=5
# [70]#011train-error:0.096355
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 18 pruned nodes, max_depth=5
# [71]#011train-error:0.096528
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 28 pruned nodes, max_depth=4
# [72]#011train-error:0.096389
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [73]#011train-error:0.096181
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 18 pruned nodes, max_depth=5
# [74]#011train-error:0.096112
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 30 pruned nodes, max_depth=5
# [75]#011train-error:0.095973
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [76]#011train-error:0.096251
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [77]#011train-error:0.096042
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 16 pruned nodes, max_depth=3
# [78]#011train-error:0.095904
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 30 pruned nodes, max_depth=5
# [79]#011train-error:0.0958
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 20 pruned nodes, max_depth=5
# [80]#011train-error:0.095661
# [21:31:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [81]#011train-error:0.095661
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 24 pruned nodes, max_depth=5
# [82]#011train-error:0.095487
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [83]#011train-error:0.095453
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 20 pruned nodes, max_depth=5
# [84]#011train-error:0.095349
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [85]#011train-error:0.095418
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 22 pruned nodes, max_depth=5
# [86]#011train-error:0.095418
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 36 pruned nodes, max_depth=4
# [87]#011train-error:0.095418
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 26 pruned nodes, max_depth=5
# [88]#011train-error:0.095487
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 30 pruned nodes, max_depth=5
# [89]#011train-error:0.095175
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 18 pruned nodes, max_depth=5
# [90]#011train-error:0.095314
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 18 pruned nodes, max_depth=4
# [91]#011train-error:0.095141
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 30 pruned nodes, max_depth=5
# [92]#011train-error:0.095245
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 22 pruned nodes, max_depth=5
# [93]#011train-error:0.095314
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 30 pruned nodes, max_depth=5
# [94]#011train-error:0.095279
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 38 pruned nodes, max_depth=5
# [95]#011train-error:0.095349
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 18 pruned nodes, max_depth=5
# [96]#011train-error:0.09521
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 26 pruned nodes, max_depth=5
# [97]#011train-error:0.095071
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [98]#011train-error:0.095106
# [21:31:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 24 pruned nodes, max_depth=5
# [99]#011train-error:0.094759
#
# 2022-04-07 21:31:33 Uploading - Uploading generated training model
# 2022-04-07 21:31:33 Completed - Training job completed
# Training seconds: 123
# Billable seconds: 123
# RESULT: Training completed.
# ----------!CREATED: model server
# RESULT: Accuracy is 89.7%.
